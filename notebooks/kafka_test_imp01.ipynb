# %%
import requests
import json
from datetime import datetime

# %%
CITY= {
    "name":"shimla",
    "latitude":31.10,
    "longitude":77.17
}

print(CITY)
# Out:
# {'name': 'shimla', 'latitude': 31.1, 'longitude': 71.17}

# %%
#build weather api url
BASE_URL = "https://api.open-meteo.com/v1/forecast"
latitude=CITY["latitude"]
longitude=CITY["longitude"]

url=(
    f"{BASE_URL}"
    f"?latitude={latitude}"
    f"&longitude={longitude}"
    f"&current=temperature_2m,relative_humidity_2m,"
    f"wind_speed_10m,pressure_msl"


)

print(url)
# Out:
# https://api.open-meteo.com/v1/forecast?latitude=31.1&longitude=71.17&current=temperature_2m,relative_humidity_2m,wind_speed_10m,pressure_msl

# %%
#send request
response= requests.get(url)
print(response)
# Out:
# <Response [200]>

# %%
print(response.status_code)
# Out:
# 200

# %%
#json response
weather_data=response.json()
print(json.dumps(weather_data,indent=4))
# Out:
# {
#     "latitude": 31.107204,
#     "longitude": 71.187645,
#     "generationtime_ms": 0.06389617919921875,
#     "utc_offset_seconds": 0,
#     "timezone": "GMT",
#     "timezone_abbreviation": "GMT",
#     "elevation": 153.0,
#     "current_units": {
#         "time": "iso8601",
#         "interval": "seconds",
#         "temperature_2m": "\u00b0C",
#         "relative_humidity_2m": "%",
#         "wind_speed_10m": "km/h",
#         "pressure_msl": "hPa"
#     },
#     "current": {
#         "time": "2026-06-26T16:00",
#         "interval": 900,
#         "temperature_2m": 33.3,
#         "relative_humidity_2m": 53,
#         "wind_speed_10m": 8.2,
#         "pressure_msl": 1001.3
#     }
# }

# %%
## event modelling and event creation

print(weather_data.keys())
# Out:
# dict_keys(['latitude', 'longitude', 'generationtime_ms', 'utc_offset_seconds', 'timezone', 'timezone_abbreviation', 'elevation', 'current_units', 'current'])

# %%
current=weather_data["current"]
print(json.dumps(current,indent=4))
# Out:
# {
#     "time": "2026-06-26T16:00",
#     "interval": 900,
#     "temperature_2m": 33.3,
#     "relative_humidity_2m": 53,
#     "wind_speed_10m": 8.2,
#     "pressure_msl": 1001.3
# }

# %%
##create weather event
print(weather_data.keys())
# Out:
# dict_keys(['latitude', 'longitude', 'generationtime_ms', 'utc_offset_seconds', 'timezone', 'timezone_abbreviation', 'elevation', 'current_units', 'current'])

# %%
#create weather event
weather_event={
      "city":CITY["name"],
      "temperature_c":current["temperature_2m"],
      "humidity_percent":current["relative_humidity_2m"],
      "wind_speed_kmh":current["wind_speed_10m"],
      "pressure_hpa":current["pressure_msl"],
      "event_time":current["time"],
      "producer_timestamp":datetime.now().isoformat()
}

print(json.dumps(weather_event,indent=4))
# Out:
# {
#     "city": "shimla",
#     "temperature_c": 33.3,
#     "humidity_percent": 53,
#     "wind_speed_kmh": 8.2,
#     "pressure_hpa": 1001.3,
#     "event_time": "2026-06-26T16:00",
#     "producer_timestamp": "2026-06-26T21:49:10.590586"
# }

# %%
print(type(weather_event))
print(weather_event.keys())
# Out:
# <class 'dict'>
# dict_keys(['city', 'temperature_c', 'humidity_percent', 'wind_speed_kmh', 'pressure_hpa', 'event_time', 'producer_timestamp'])
